# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
from pprint import pprint
#from adjustText import adjust_text

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 587

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    units="metric"
    query_url=f"{url}appid={weather_api_key}&units={units}&q="
    city_url = query_url + city

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat =  city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp =  city_weather['main']["temp_max"]
        city_humidity = city_weather['main']["humidity"]
        city_clouds = city_weather['clouds']["all"]
        city_wind = city_weather['wind']["speed"]
        city_country = city_weather['sys']["country"]
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | iqaluit
# Processing Record 2 of Set 1 | longyearbyen
# Processing Record 3 of Set 1 | edinburgh of the seven seas
# Processing Record 4 of Set 1 | stanley
# Processing Record 5 of Set 1 | amarante do maranhao
# Processing Record 6 of Set 1 | adamstown
# Processing Record 7 of Set 1 | kodiak
# Processing Record 8 of Set 1 | waitangi
# Processing Record 9 of Set 1 | olonkinbyen
# Processing Record 10 of Set 1 | margaret river
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | nagqu
# Processing Record 13 of Set 1 | pisco
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | lazaro cardenas
# Processing Record 16 of Set 1 | puerto natales
# Processing Record 17 of Set 1 | ippy
# Processing Record 18 of Set 1 | port mathurin
# Processing Record 19 of Set 1 | okha
# Processing Record 20 of Set 1 | vorgashor
# Processing Record 21 of Set 1 | lebu
# Processing Record 22 of Set 1 | blackmans bay
# Processing Record 23 of Set 1 | port-aux-francais
# Processing Record 24 of Set 1 | kapa'a
# Processing Record 25 of Set 1 | alice springs
# Processing Record 26 of Set 1 | oskarshamn
# Processing Record 27 of Set 1 | bredasdorp
# Processing Record 28 of Set 1 | tazovsky
# Processing Record 29 of Set 1 | whitehorse
# Processing Record 30 of Set 1 | pop
# Processing Record 31 of Set 1 | mont-laurier
# Processing Record 32 of Set 1 | rongelap
# Processing Record 33 of Set 1 | newman
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | utrik
# Processing Record 36 of Set 1 | invercargill
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | aswan
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | grytviken
# Processing Record 41 of Set 1 | college
# Processing Record 42 of Set 1 | badger
# Processing Record 43 of Set 1 | happy valley-goose bay
# Processing Record 44 of Set 1 | cariati
# Processing Record 45 of Set 1 | almazan
# Processing Record 46 of Set 1 | mana
# Processing Record 47 of Set 1 | lihue
# Processing Record 48 of Set 1 | ilulissat
# Processing Record 49 of Set 1 | bardai
# Processing Record 50 of Set 1 | arraial do cabo
# Processing Record 0 of Set 2 | hithadhoo
# Processing Record 1 of Set 2 | uiju
# Processing Record 2 of Set 2 | namibe
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | carnarvon
# Processing Record 5 of Set 2 | villa hernandarias
# Processing Record 6 of Set 2 | south grafton
# Processing Record 7 of Set 2 | ketchikan
# Processing Record 8 of Set 2 | sherbakul'
# Processing Record 9 of Set 2 | nyurba
# Processing Record 10 of Set 2 | nikel
# Processing Record 11 of Set 2 | wailua homesteads
# Processing Record 12 of Set 2 | ponta delgada
# Processing Record 13 of Set 2 | constantia
# Processing Record 14 of Set 2 | mezhdurechenskiy
# Processing Record 15 of Set 2 | bethel
# Processing Record 16 of Set 2 | gawan
# Processing Record 17 of Set 2 | amga
# Processing Record 18 of Set 2 | tirat karmel
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | acarau
# Processing Record 22 of Set 2 | alotau
# Processing Record 23 of Set 2 | punta arenas
# Processing Record 24 of Set 2 | hilton
# Processing Record 25 of Set 2 | elmendorf air force base
# City not found. Skipping...
# Processing Record 26 of Set 2 | tiksi
# Processing Record 27 of Set 2 | kamloops
# Processing Record 28 of Set 2 | quelimane
# Processing Record 29 of Set 2 | san pedro pochutla
# Processing Record 30 of Set 2 | ibiza
# Processing Record 31 of Set 2 | howrah
# Processing Record 32 of Set 2 | caleta de carquin
# Processing Record 33 of Set 2 | ancud
# Processing Record 34 of Set 2 | syanno
# Processing Record 35 of Set 2 | greenville
# Processing Record 36 of Set 2 | mount isa
# Processing Record 37 of Set 2 | zhezqazghan
# Processing Record 38 of Set 2 | usinsk
# Processing Record 39 of Set 2 | kruisfontein
# Processing Record 40 of Set 2 | mananjary
# Processing Record 41 of Set 2 | madimba
# Processing Record 42 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 43 of Set 2 | greymouth
# Processing Record 44 of Set 2 | shahrak
# Processing Record 45 of Set 2 | haiku-pauwela
# Processing Record 46 of Set 2 | bam
# Processing Record 47 of Set 2 | sandnessjoen
# Processing Record 48 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 49 of Set 2 | enewetak
# Processing Record 0 of Set 3 | uturoa
# Processing Record 1 of Set 3 | novodvinsk
# Processing Record 2 of Set 3 | codrington
# Processing Record 3 of Set 3 | bilibino
# Processing Record 4 of Set 3 | koraput
# Processing Record 5 of Set 3 | port said
# Processing Record 6 of Set 3 | vernon
# Processing Record 7 of Set 3 | hamilton
# Processing Record 8 of Set 3 | tahe
# Processing Record 9 of Set 3 | altay
# Processing Record 10 of Set 3 | six-fours-les-plages
# Processing Record 11 of Set 3 | cooma
# Processing Record 12 of Set 3 | tommot
# Processing Record 13 of Set 3 | bamboo flat
# Processing Record 14 of Set 3 | terekli-mekteb
# Processing Record 15 of Set 3 | kuanda
# Processing Record 16 of Set 3 | kudahuvadhoo
# Processing Record 17 of Set 3 | kayangel
# Processing Record 18 of Set 3 | ahau
# City not found. Skipping...
# Processing Record 19 of Set 3 | ocean city
# Processing Record 20 of Set 3 | mahina
# Processing Record 21 of Set 3 | fale old settlement
# Processing Record 22 of Set 3 | talnakh
# Processing Record 23 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 24 of Set 3 | nakanojomachi
# Processing Record 25 of Set 3 | charlton kings
# Processing Record 26 of Set 3 | qaqortoq
# Processing Record 27 of Set 3 | antalaha
# Processing Record 28 of Set 3 | argo
# Processing Record 29 of Set 3 | afaahiti
# Processing Record 30 of Set 3 | fort mcmurray
# Processing Record 31 of Set 3 | puerto aysen
# Processing Record 32 of Set 3 | severo-yeniseyskiy
# Processing Record 33 of Set 3 | labytnangi
# Processing Record 34 of Set 3 | kirensk
# Processing Record 35 of Set 3 | lekki
# Processing Record 36 of Set 3 | atafu village
# Processing Record 37 of Set 3 | avarua
# Processing Record 38 of Set 3 | tual
# Processing Record 39 of Set 3 | keflavik
# Processing Record 40 of Set 3 | owen sound
# Processing Record 41 of Set 3 | fayroz koh
# Processing Record 42 of Set 3 | cestos city
# Processing Record 43 of Set 3 | villa gesell
# Processing Record 44 of Set 3 | madinat ash shamal
# Processing Record 45 of Set 3 | arles
# Processing Record 46 of Set 3 | karaton
# Processing Record 47 of Set 3 | nova vicosa
# Processing Record 48 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 49 of Set 3 | floro
# Processing Record 0 of Set 4 | tres lagoas
# Processing Record 1 of Set 4 | merizo village
# Processing Record 2 of Set 4 | bandarbeyla
# Processing Record 3 of Set 4 | bassila
# Processing Record 4 of Set 4 | touros
# Processing Record 5 of Set 4 | hunchun
# Processing Record 6 of Set 4 | auki
# Processing Record 7 of Set 4 | rojhan
# Processing Record 8 of Set 4 | motueka
# Processing Record 9 of Set 4 | malkara
# Processing Record 10 of Set 4 | papatowai
# Processing Record 11 of Set 4 | vilyuchinsk
# Processing Record 12 of Set 4 | vadso
# Processing Record 13 of Set 4 | chonchi
# Processing Record 14 of Set 4 | geraldton
# Processing Record 15 of Set 4 | rupert
# Processing Record 16 of Set 4 | harper
# Processing Record 17 of Set 4 | isafjordur
# Processing Record 18 of Set 4 | cidreira
# Processing Record 19 of Set 4 | nan
# Processing Record 20 of Set 4 | arkhangel'sk
# Processing Record 21 of Set 4 | timbuktu
# Processing Record 22 of Set 4 | mandera
# Processing Record 23 of Set 4 | uzda
# Processing Record 24 of Set 4 | nesterovskaya
# Processing Record 25 of Set 4 | klyuchi
# Processing Record 26 of Set 4 | poxoreo
# Processing Record 27 of Set 4 | marysville
# Processing Record 28 of Set 4 | susuman
# Processing Record 29 of Set 4 | embi
# Processing Record 30 of Set 4 | comodoro rivadavia
# Processing Record 31 of Set 4 | meulaboh
# Processing Record 32 of Set 4 | castillos
# Processing Record 33 of Set 4 | raduzhny
# Processing Record 34 of Set 4 | tura
# Processing Record 35 of Set 4 | san antonio de pale
# Processing Record 36 of Set 4 | jamestown
# Processing Record 37 of Set 4 | west island
# Processing Record 38 of Set 4 | san luis
# Processing Record 39 of Set 4 | bela vista
# Processing Record 40 of Set 4 | neiafu
# Processing Record 41 of Set 4 | zachary
# Processing Record 42 of Set 4 | ndago
# Processing Record 43 of Set 4 | i-n-salah
# Processing Record 44 of Set 4 | murzuq
# Processing Record 45 of Set 4 | kamaishi
# Processing Record 46 of Set 4 | salida
# Processing Record 47 of Set 4 | dawson creek
# Processing Record 48 of Set 4 | fort bragg
# Processing Record 49 of Set 4 | anadyr
# Processing Record 0 of Set 5 | port alfred
# Processing Record 1 of Set 5 | machico
# Processing Record 2 of Set 5 | val-d'or
# Processing Record 3 of Set 5 | bardsir
# Processing Record 4 of Set 5 | celldomolk
# Processing Record 5 of Set 5 | magadan
# Processing Record 6 of Set 5 | shangri-la
# City not found. Skipping...
# Processing Record 7 of Set 5 | xiva
# Processing Record 8 of Set 5 | homosassa springs
# Processing Record 9 of Set 5 | kampung sungai ara
# Processing Record 10 of Set 5 | roswell
# Processing Record 11 of Set 5 | horta
# Processing Record 12 of Set 5 | maxixe
# Processing Record 13 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 14 of Set 5 | malaut
# Processing Record 15 of Set 5 | datca
# Processing Record 16 of Set 5 | mangrol
# Processing Record 17 of Set 5 | nelson
# Processing Record 18 of Set 5 | obo
# Processing Record 19 of Set 5 | cidade velha
# Processing Record 20 of Set 5 | aasiaat
# Processing Record 21 of Set 5 | coquimbo
# Processing Record 22 of Set 5 | lerwick
# Processing Record 23 of Set 5 | ammi moussa
# Processing Record 24 of Set 5 | st. john's
# Processing Record 25 of Set 5 | port lincoln
# Processing Record 26 of Set 5 | conceicao da barra
# Processing Record 27 of Set 5 | dudinka
# Processing Record 28 of Set 5 | buguias
# Processing Record 29 of Set 5 | jieshi
# Processing Record 30 of Set 5 | ribeira grande
# Processing Record 31 of Set 5 | buala
# Processing Record 32 of Set 5 | jaguaribe
# Processing Record 33 of Set 5 | ulladulla
# Processing Record 34 of Set 5 | luziania
# Processing Record 35 of Set 5 | ayabaca
# Processing Record 36 of Set 5 | arawa
# Processing Record 37 of Set 5 | thurso
# Processing Record 38 of Set 5 | cable beach
# City not found. Skipping...
# Processing Record 39 of Set 5 | manturovo
# Processing Record 40 of Set 5 | kokofata
# City not found. Skipping...
# Processing Record 41 of Set 5 | the dalles
# Processing Record 42 of Set 5 | katrineholm
# Processing Record 43 of Set 5 | mil'kovo
# Processing Record 44 of Set 5 | wangjing
# Processing Record 45 of Set 5 | zabol
# Processing Record 46 of Set 5 | chervyen'
# Processing Record 47 of Set 5 | thompson
# Processing Record 48 of Set 5 | fort-shevchenko
# Processing Record 49 of Set 5 | miandrivazo
# Processing Record 0 of Set 6 | pokhara
# Processing Record 1 of Set 6 | itoman
# Processing Record 2 of Set 6 | amanalco de becerra
# Processing Record 3 of Set 6 | ust-nera
# Processing Record 4 of Set 6 | brisas de zicatela
# Processing Record 5 of Set 6 | arteche
# Processing Record 6 of Set 6 | lospalos
# Processing Record 7 of Set 6 | tecpan de galeana
# Processing Record 8 of Set 6 | kokpekty
# Processing Record 9 of Set 6 | al kharijah
# Processing Record 10 of Set 6 | togur
# Processing Record 11 of Set 6 | skowhegan
# Processing Record 12 of Set 6 | udachny
# Processing Record 13 of Set 6 | espoo
# Processing Record 14 of Set 6 | alegrete
# Processing Record 15 of Set 6 | broome
# Processing Record 16 of Set 6 | paita
# Processing Record 17 of Set 6 | tangalle
# Processing Record 18 of Set 6 | la ronge
# Processing Record 19 of Set 6 | san sebastian de la gomera
# Processing Record 20 of Set 6 | kasongo-lunda
# Processing Record 21 of Set 6 | nemuro
# Processing Record 22 of Set 6 | sorong
# Processing Record 23 of Set 6 | zhaqsy
# Processing Record 24 of Set 6 | luanshya
# Processing Record 25 of Set 6 | akjoujt
# Processing Record 26 of Set 6 | kavieng
# Processing Record 27 of Set 6 | porto velho
# Processing Record 28 of Set 6 | mayen abun
# City not found. Skipping...
# Processing Record 29 of Set 6 | siwa oasis
# Processing Record 30 of Set 6 | yaring
# Processing Record 31 of Set 6 | iskateley
# Processing Record 32 of Set 6 | maiwut
# City not found. Skipping...
# Processing Record 33 of Set 6 | sitka
# Processing Record 34 of Set 6 | yinchuan
# Processing Record 35 of Set 6 | gedo
# Processing Record 36 of Set 6 | nadi
# Processing Record 37 of Set 6 | kilindoni
# Processing Record 38 of Set 6 | patnongon
# Processing Record 39 of Set 6 | khandyga
# Processing Record 40 of Set 6 | mogocha
# Processing Record 41 of Set 6 | akureyri
# Processing Record 42 of Set 6 | sosnovo-ozerskoye
# Processing Record 43 of Set 6 | san jose village
# City not found. Skipping...
# Processing Record 44 of Set 6 | katsuura
# Processing Record 45 of Set 6 | pahrump
# Processing Record 46 of Set 6 | lianran
# Processing Record 47 of Set 6 | east london
# Processing Record 48 of Set 6 | yeed
# Processing Record 49 of Set 6 | filadelfia
# Processing Record 0 of Set 7 | saldanha
# Processing Record 1 of Set 7 | sola
# Processing Record 2 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 3 of Set 7 | saint-leu
# Processing Record 4 of Set 7 | akita
# Processing Record 5 of Set 7 | polyarnyy
# Processing Record 6 of Set 7 | geiro
# Processing Record 7 of Set 7 | east ballina
# Processing Record 8 of Set 7 | yaren
# Processing Record 9 of Set 7 | arfoud
# Processing Record 10 of Set 7 | barabai
# Processing Record 11 of Set 7 | giddings
# Processing Record 12 of Set 7 | sinop
# Processing Record 13 of Set 7 | laizhou
# Processing Record 14 of Set 7 | cabo san lucas
# Processing Record 15 of Set 7 | sol'tsy
# Processing Record 16 of Set 7 | gorontalo
# Processing Record 17 of Set 7 | flying fish cove
# Processing Record 18 of Set 7 | puerto san jose
# Processing Record 19 of Set 7 | brookings
# Processing Record 20 of Set 7 | santa catalina
# Processing Record 21 of Set 7 | whitecourt
# Processing Record 22 of Set 7 | prachuap khiri khan
# Processing Record 23 of Set 7 | dakhla
# Processing Record 24 of Set 7 | vohipaho
# City not found. Skipping...
# Processing Record 25 of Set 7 | viedma
# Processing Record 26 of Set 7 | saipan
# Processing Record 27 of Set 7 | jiagedaqi
# Processing Record 28 of Set 7 | hasaki
# Processing Record 29 of Set 7 | kronoby
# Processing Record 30 of Set 7 | turkmenbasy
# Processing Record 31 of Set 7 | espargos
# City not found. Skipping...
# Processing Record 32 of Set 7 | mora
# Processing Record 33 of Set 7 | puerto leguizamo
# Processing Record 34 of Set 7 | porto novo
# Processing Record 35 of Set 7 | thames
# Processing Record 36 of Set 7 | progreso
# Processing Record 37 of Set 7 | robertsport
# Processing Record 38 of Set 7 | kirakira
# Processing Record 39 of Set 7 | sovetskaya gavan'
# Processing Record 40 of Set 7 | acapulco de juarez
# Processing Record 41 of Set 7 | soe
# Processing Record 42 of Set 7 | yakeshi
# Processing Record 43 of Set 7 | carutapera
# Processing Record 44 of Set 7 | al kharj
# Processing Record 45 of Set 7 | mar del plata
# Processing Record 46 of Set 7 | saint-philippe
# Processing Record 47 of Set 7 | kapuskasing
# Processing Record 48 of Set 7 | yangor
# City not found. Skipping...
# Processing Record 49 of Set 7 | colonia
# Processing Record 0 of Set 8 | roberval
# Processing Record 1 of Set 8 | beinamar
# Processing Record 2 of Set 8 | tchintabaraden
# Processing Record 3 of Set 8 | seguin
# Processing Record 4 of Set 8 | sapele
# Processing Record 5 of Set 8 | mata-utu
# Processing Record 6 of Set 8 | zomin shaharchasi
# City not found. Skipping...
# Processing Record 7 of Set 8 | mchinji
# Processing Record 8 of Set 8 | siwana
# Processing Record 9 of Set 8 | carbonear
# Processing Record 10 of Set 8 | ingeniero jacobacci
# Processing Record 11 of Set 8 | inderbor
# Processing Record 12 of Set 8 | tsiombe
# Processing Record 13 of Set 8 | quepos
# Processing Record 14 of Set 8 | nova sintra
# Processing Record 15 of Set 8 | shingu
# Processing Record 16 of Set 8 | eastham
# Processing Record 17 of Set 8 | cabinda
# Processing Record 18 of Set 8 | enkoping
# Processing Record 19 of Set 8 | maputo
# Processing Record 20 of Set 8 | changsu
# Processing Record 21 of Set 8 | betio village
# Processing Record 22 of Set 8 | shahdol
# Processing Record 23 of Set 8 | oliver
# Processing Record 24 of Set 8 | nong khai
# Processing Record 25 of Set 8 | lucheng
# Processing Record 26 of Set 8 | sarkand
# Processing Record 27 of Set 8 | la'ie
# Processing Record 28 of Set 8 | kill devil hills
# Processing Record 29 of Set 8 | mejit
# Processing Record 30 of Set 8 | remire-montjoly
# Processing Record 31 of Set 8 | spring creek
# Processing Record 32 of Set 8 | alvand
# Processing Record 33 of Set 8 | shwebo
# Processing Record 34 of Set 8 | reggane
# Processing Record 35 of Set 8 | ostersund
# Processing Record 36 of Set 8 | fort irwin
# Processing Record 37 of Set 8 | kerikeri
# Processing Record 38 of Set 8 | gusinoozyorsk
# Processing Record 39 of Set 8 | amberg
# Processing Record 40 of Set 8 | cockburn town
# Processing Record 41 of Set 8 | tolanaro
# Processing Record 42 of Set 8 | shimoda
# Processing Record 43 of Set 8 | belle fourche
# Processing Record 44 of Set 8 | bodo
# Processing Record 45 of Set 8 | arboga
# Processing Record 46 of Set 8 | bodaybo
# Processing Record 47 of Set 8 | minas de marcona
# Processing Record 48 of Set 8 | kununurra
# Processing Record 49 of Set 8 | khadan khak
# Processing Record 0 of Set 9 | nuuk
# Processing Record 1 of Set 9 | quellon
# Processing Record 2 of Set 9 | poronaysk
# Processing Record 3 of Set 9 | prince rupert
# Processing Record 4 of Set 9 | kendari
# Processing Record 5 of Set 9 | aldan
# Processing Record 6 of Set 9 | sao francisco de paula
# Processing Record 7 of Set 9 | nacimiento
# Processing Record 8 of Set 9 | las tablas
# Processing Record 9 of Set 9 | okhotsk
# Processing Record 10 of Set 9 | dunedin
# Processing Record 11 of Set 9 | novovarshavka
# Processing Record 12 of Set 9 | hawaiian paradise park
# Processing Record 13 of Set 9 | kuusamo
# Processing Record 14 of Set 9 | karratha
# Processing Record 15 of Set 9 | struer
# Processing Record 16 of Set 9 | trondheim
# Processing Record 17 of Set 9 | grande prairie
# Processing Record 18 of Set 9 | ebaye
# Processing Record 19 of Set 9 | kangaba
# Processing Record 20 of Set 9 | onguday
# Processing Record 21 of Set 9 | lyubim
# Processing Record 22 of Set 9 | colonel hill
# Processing Record 23 of Set 9 | natal
# Processing Record 24 of Set 9 | dryden
# Processing Record 25 of Set 9 | arkalyk
# Processing Record 26 of Set 9 | zhuanghe
# Processing Record 27 of Set 9 | dwarka
# Processing Record 28 of Set 9 | ballina
# Processing Record 29 of Set 9 | changji
# Processing Record 30 of Set 9 | aral
# Processing Record 31 of Set 9 | puerto ayacucho
# Processing Record 32 of Set 9 | zakynthos
# Processing Record 33 of Set 9 | antsiranana
# Processing Record 34 of Set 9 | copala
# Processing Record 35 of Set 9 | othello
# Processing Record 36 of Set 9 | toga village
# City not found. Skipping...
# Processing Record 37 of Set 9 | horasan
# Processing Record 38 of Set 9 | luanda
# Processing Record 39 of Set 9 | duragan
# Processing Record 40 of Set 9 | ribeira brava
# Processing Record 41 of Set 9 | seven pagodas
# Processing Record 42 of Set 9 | fagaras
# Processing Record 43 of Set 9 | port hedland
# Processing Record 44 of Set 9 | al bawiti
# Processing Record 45 of Set 9 | kataragama
# City not found. Skipping...
# Processing Record 46 of Set 9 | wangqing
# Processing Record 47 of Set 9 | las vegas
# Processing Record 48 of Set 9 | ocara
# Processing Record 49 of Set 9 | makokou
# Processing Record 0 of Set 10 | castro alves
# Processing Record 1 of Set 10 | torres
# Processing Record 2 of Set 10 | taltal
# Processing Record 3 of Set 10 | wamba
# Processing Record 4 of Set 10 | yambio
# Processing Record 5 of Set 10 | amursk
# Processing Record 6 of Set 10 | fortuna
# Processing Record 7 of Set 10 | praia da vitoria
# Processing Record 8 of Set 10 | sumbawa besar
# Processing Record 9 of Set 10 | kargopol'
# Processing Record 10 of Set 10 | huanta
# Processing Record 11 of Set 10 | labrador city
# Processing Record 12 of Set 10 | lysekil
# Processing Record 13 of Set 10 | murashi
# Processing Record 14 of Set 10 | visselhovede
# Processing Record 15 of Set 10 | penafiel
# Processing Record 16 of Set 10 | westport
# Processing Record 17 of Set 10 | paulista florida
# Processing Record 18 of Set 10 | prince albert
# Processing Record 19 of Set 10 | fisterra
# Processing Record 20 of Set 10 | penalva
# Processing Record 21 of Set 10 | vysokiy
# Processing Record 22 of Set 10 | devinuwara
# City not found. Skipping...
# Processing Record 23 of Set 10 | archidona
# Processing Record 24 of Set 10 | ola
# Processing Record 25 of Set 10 | burutu
# Processing Record 26 of Set 10 | banff
# Processing Record 27 of Set 10 | ilhabela
# Processing Record 28 of Set 10 | muzayri'
# City not found. Skipping...
# Processing Record 29 of Set 10 | basco
# Processing Record 30 of Set 10 | pemba
# Processing Record 31 of Set 10 | bugana
# Processing Record 32 of Set 10 | yanchep
# Processing Record 33 of Set 10 | albertina
# Processing Record 34 of Set 10 | puerto baquerizo moreno
# Processing Record 35 of Set 10 | koumra
# Processing Record 36 of Set 10 | puerto rico
# Processing Record 37 of Set 10 | mombetsu
# Processing Record 38 of Set 10 | sur
# Processing Record 39 of Set 10 | la passe
# Processing Record 40 of Set 10 | tshabong
# Processing Record 41 of Set 10 | ivdel'
# Processing Record 42 of Set 10 | guercif
# Processing Record 43 of Set 10 | zinjibar
# Processing Record 44 of Set 10 | suez
# Processing Record 45 of Set 10 | kabala
# Processing Record 46 of Set 10 | tazacorte
# Processing Record 47 of Set 10 | weno
# Processing Record 48 of Set 10 | bayan nur
# City not found. Skipping...
# Processing Record 49 of Set 10 | launceston
# Processing Record 0 of Set 11 | ar ruways
# Processing Record 1 of Set 11 | naze
# Processing Record 2 of Set 11 | san patricio
# Processing Record 3 of Set 11 | tadmur
# Processing Record 4 of Set 11 | mokhsogollokh
# Processing Record 5 of Set 11 | margate
# Processing Record 6 of Set 11 | bom jesus
# Processing Record 7 of Set 11 | mogok
# Processing Record 8 of Set 11 | san pedro carcha
# Processing Record 9 of Set 11 | luderitz
# Processing Record 10 of Set 11 | palikir - national government center
# Processing Record 11 of Set 11 | sibut
# Processing Record 12 of Set 11 | harstad
# Processing Record 13 of Set 11 | boyolangu
# Processing Record 14 of Set 11 | lionel town
# Processing Record 15 of Set 11 | demidov
# Processing Record 16 of Set 11 | santa ana
# Processing Record 17 of Set 11 | galle
# Processing Record 18 of Set 11 | new plymouth
# Processing Record 19 of Set 11 | chulakkurgan
# Processing Record 20 of Set 11 | yirga 'alem
# City not found. Skipping...
# Processing Record 21 of Set 11 | sarandi del yi
# Processing Record 22 of Set 11 | necochea
# Processing Record 23 of Set 11 | baskale
# Processing Record 24 of Set 11 | cadillac
# Processing Record 25 of Set 11 | lompoc
# Processing Record 26 of Set 11 | frutal
# Processing Record 27 of Set 11 | bolobo
# Processing Record 28 of Set 11 | salekhard
# Processing Record 29 of Set 11 | sidney
# Processing Record 30 of Set 11 | costa rica
# Processing Record 31 of Set 11 | amlapura
# Processing Record 32 of Set 11 | ivanteyevka
# Processing Record 33 of Set 11 | nirgua
# Processing Record 34 of Set 11 | bel ombre
# Processing Record 35 of Set 11 | bossangoa
# Processing Record 36 of Set 11 | dengzhou
# Processing Record 37 of Set 11 | cativa
# Processing Record 38 of Set 11 | nema
# Processing Record 39 of Set 11 | agadez
# Processing Record 40 of Set 11 | corn island
# Processing Record 41 of Set 11 | roshchino
# Processing Record 42 of Set 11 | palmares do sul
# Processing Record 43 of Set 11 | grand falls-windsor
# Processing Record 44 of Set 11 | kalabo
# Processing Record 45 of Set 11 | el calafate
# Processing Record 46 of Set 11 | port saint john's
# Processing Record 47 of Set 11 | cambridge
# Processing Record 48 of Set 11 | holualoa
# Processing Record 49 of Set 11 | yuxi
# Processing Record 0 of Set 12 | stara vyzhivka
# Processing Record 1 of Set 12 | nishinoomote
# Processing Record 2 of Set 12 | zarghun shahr
# Processing Record 3 of Set 12 | lorengau
# Processing Record 4 of Set 12 | hammerfest
# Processing Record 5 of Set 12 | delice
# Processing Record 6 of Set 12 | lima
# Processing Record 7 of Set 12 | saint-christol-les-ales
# Processing Record 8 of Set 12 | tralee
# Processing Record 9 of Set 12 | shenjiamen
# Processing Record 10 of Set 12 | yuzhno-kurilsk
# Processing Record 11 of Set 12 | egilsstadir
# Processing Record 12 of Set 12 | kyain seikgyi township
# City not found. Skipping...
# Processing Record 13 of Set 12 | bridgewater
# Processing Record 14 of Set 12 | jessore
# Processing Record 15 of Set 12 | george town
# Processing Record 16 of Set 12 | notodden
# Processing Record 17 of Set 12 | coari
# Processing Record 18 of Set 12 | agat village
# Processing Record 19 of Set 12 | charlottetown
# Processing Record 20 of Set 12 | queenstown
# Processing Record 21 of Set 12 | nar'yan-mar
# Processing Record 22 of Set 12 | mermoz boabab
# Processing Record 23 of Set 12 | laojunmiao
# Processing Record 24 of Set 12 | herat
# Processing Record 25 of Set 12 | beitbridge
# Processing Record 26 of Set 12 | tsagan aman
# Processing Record 27 of Set 12 | hue
# Processing Record 28 of Set 12 | hadibu
# Processing Record 29 of Set 12 | guatrache
# Processing Record 30 of Set 12 | homer
# Processing Record 31 of Set 12 | margherita
# Processing Record 32 of Set 12 | naha
# Processing Record 33 of Set 12 | muynoq
# Processing Record 34 of Set 12 | antibes
# Processing Record 35 of Set 12 | oxapampa
# Processing Record 36 of Set 12 | sanctuary point
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          563
# Lat           563
# Lng           563
# Max Temp      563
# Humidity      563
# Cloudiness    563
# Wind Speed    563
# Country       563
# Date          563
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat      Lng  Max Temp  Humidity  \
# 0                      iqaluit  63.7506 -68.5145     13.85        58
# 1                 longyearbyen  78.2186  15.6401      9.91        87
# 2  edinburgh of the seven seas -37.0676 -12.3116     11.13        61
# 3                      stanley  54.8680  -1.6985     13.01        75
# 4         amarante do maranhao  -5.5667 -46.7422     36.19        18
#
#    Cloudiness  Wind Speed Country        Date
# 0          75        8.23      CA  1724183624
# 1          75        4.63      SJ  1724183625
# 2         100       12.98      SH  1724183626
# 3          20        6.17      GB  1724183628
# 4           0        2.57      BR  1724183629

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 0                            iqaluit  63.7506 -68.5145     13.85        58
# 1                       longyearbyen  78.2186  15.6401      9.91        87
# 2        edinburgh of the seven seas -37.0676 -12.3116     11.13        61
# 3                            stanley  54.8680  -1.6985     13.01        75
# 4               amarante do maranhao  -5.5667 -46.7422     36.19        18
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                75        8.23      CA  1724183624
# 1                75        4.63      SJ  1724183625
# 2               100       12.98      SH  1724183626
# 3                20        6.17      GB  1724183628
# 4                 0        2.57      BR  1724183629

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values, edgecolor="black")


# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature(C)')
plt.title(f"City Max Latitude vs Temperature(2024-06-17)")
plt.grid()


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values,y_values, edgecolor="black")


# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f"City Latitude vs Humidity(2024-06-17)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values,y_values, edgecolor="black")


# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title(f"City Latitude vs Cloudiness(2024-06-17)")
plt.grid()


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values, edgecolor="black")


# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')
plt.title(f"City Latitude vs Wind Speed(2024-06-17)")
plt.grid()


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression_plots(x_values, y_values, title, x_label, y_label):
    
# Perform a linear regression on temperature vs. latitude
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)

# Get regression values
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
# Annotate the line equation
   
    plt.annotate(line_eq,(0.05, 0.95),xycoords='axes fraction', verticalalignment='top', fontsize=15,color="red")
    

 #Label the plot
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
   

# Print r^2 value
    print(f"The r^2-value is: {rvalue**2}")

# Show plot
    plt.show()
    
    

    return

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=city_data_df.loc[city_data_df["Lat"]>= 0]
# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             iqaluit  63.7506  -68.5145     13.85        58          75
# 1        longyearbyen  78.2186   15.6401      9.91        87          75
# 3             stanley  54.8680   -1.6985     13.01        75          20
# 6              kodiak  57.7900 -152.4072     15.73        44           0
# 8         olonkinbyen  70.9221   -8.7187      5.12        90         100
#
#          Wind Speed Country        Date
# City_ID
# 0              8.23      CA  1724183624
# 1              4.63      SJ  1724183625
# 3              6.17      GB  1724183628
# 6              3.60      US  1724183631
# 8              3.61      SJ  1724183634

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df.loc[city_data_df["Lat"]< 0]
# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2        edinburgh of the seven seas -37.0676  -12.3116     11.13        61
# 4               amarante do maranhao  -5.5667  -46.7422     36.19        18
# 5                          adamstown -25.0660 -130.1015     17.79        58
# 7                           waitangi -43.9535 -176.5597      8.79        85
# 9                     margaret river -33.9500  115.0667     12.62        82
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2               100       12.98      SH  1724183626
# 4                 0        2.57      BR  1724183629
# 5                99        8.18      PN  1724183630
# 7                49        4.02      NZ  1724183632
# 9                74        3.51      AU  1724183635

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_regression_plots(northern_hemi_df['Lat'],northern_hemi_df['Max Temp'],"Latitude Vs. Max temp","Latitude","Max temp" )
# Out:
# The r^2-value is: 0.45976358911003606

# %%
# Linear regression on Southern Hemisphere
plt.clf()
linear_regression_plots(southern_hemi_df['Lat'],southern_hemi_df['Max Temp'],"Latitude Vs. Max temp","Latitude","Max temp" )
# Out:
# The r^2-value is: 0.6124766599237499

# %% [markdown]
# **Discussion about the linear relationship:** The equation y=−0.27x+32.12 describes a linear relationship where y decreases as x increases. The slope indicates the rate of this decrease, and the intercept gives the starting value of y when x is zero. In this case, as the Latitude value increases as you go up north in the northern hemisphere, away from the equator (latitude 0), the max temp starts to decrease.The equation y=0.43x+27.81 on the other hand, describes a linear relationship where y increases as x increases. The slope of 0.43 indicates the rate of increase in y for each unit increase in x, and the intercept of 27.81 gives the starting value of y when x is zero. In this case, as the Latitude value increases, going from -values to +values,the Max temp of the area increases as you go up north in the southern hemisphere, towards the equator where the latitude is 0.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.clf()
linear_regression_plots(northern_hemi_df['Lat'],northern_hemi_df['Humidity'],"Latitude Vs. Humidity","Latitude","Humidity" )
# Out:
# The r^2-value is: 0.000968813532266357

# %%
# Southern Hemisphere
plt.clf()
linear_regression_plots(southern_hemi_df['Lat'],southern_hemi_df['Humidity'],"Latitude Vs. Humidity","Latitude","Humidity" )
# Out:
# The r^2-value is: 0.016040102545414617

# %% [markdown]
# **Discussion about the linear relationship:** The equation y=−0.05x+74.58 describes a linear relationship where y decreases slightly as x increases. The slope of −0.05 indicates the rate of this decrease, meaning that for every unit increase in x, y decreases by 0.05 units. The intercept of 74.58 represents the initial value of y when x is zero. In this case, as the Latitude value increases, humidity gradually declines as you move up north from the equator(latitude 0) in the northern hemisphere.The equation y=−0.22x+64.63 describes a linear relationship where y decreases as x increases. The slope of −0.22 indicates that for every 1 unit increase in x, y decreases by 0.22 units. The intercept of 64.63 represents the starting value of y when x is zero. In this case, an increase in the latitude value from negative to positive in the southern hemisphere i.e a move up towards the equator(latitude 0) leads to a gradual decline in the humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.clf()
linear_regression_plots(northern_hemi_df['Lat'],northern_hemi_df['Cloudiness'],"Latitude Vs. Cloudiness","Latitude","Cloudiness" )
# Out:
# The r^2-value is: 0.007393784269768901

# %%
# Southern Hemisphere
plt.clf()
linear_regression_plots(southern_hemi_df['Lat'],southern_hemi_df['Cloudiness'],"Latitude Vs. Cloudiness","Latitude","Cloudiness" )
# Out:
# The r^2-value is: 0.010922005203260943

# %% [markdown]
# **Discussion about the linear relationship:** The equation y=−0.11x+55.83 describes a linear relationship where y decreases as x increases. The slope of −0.11 indicates that for every 1 unit increase in x, y decreases by 0.11 units. The intercept of 55.83 represents the initial value of y when x is zero. In this case, an increase in the Latitude value leads to a gradual decline in the cloudiness as you move away from the equator(latitude 0) in the northern hemisphere.The equation y=−0.62x+29.42 describes a linear relationship where y decreases as x increases. The slope of −0.62 indicates that for every 1 unit increase in x, y decreases by 0.62 units. The intercept of 29.42 represents the initial value of y when x is zero. In this case, as the Latitude value increases from negative to positive moving up north in the southern hemisphere towards the equator(latitude 0) it leads to a decrease in cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.clf()
linear_regression_plots(northern_hemi_df['Lat'],northern_hemi_df['Wind Speed'],"Latitude Vs. Wind Speed","Latitude","Wind Speed" )
# Out:
# The r^2-value is: 0.0004122160181010385

# %%
# Southern Hemisphere
plt.clf()
linear_regression_plots(southern_hemi_df['Lat'],southern_hemi_df['Wind Speed'],"Latitude Vs. Wind Speed","Latitude","Wind Speed" )
# Out:
# The r^2-value is: 0.0019556906662723025

# %% [markdown]
# **Discussion about the linear relationship:** The equation y=−0.0x+3.37 describes a situation where the dependent variable y remains constant at 3.37, regardless of the value of the independent variable x. This means that there is no relationship between x and y; y does not change as x changes. In this case, as the latitude increases as you move away from the equator(latitude 0) in the northern hemisphere, there is no impact on the wind speed as a result of it..The equation y=−0.01x+3.88 describes a linear relationship where y decreases slightly as x increases. The slope of −0.01 indicates that for every 1 unit increase in x, y decreases by just 0.01 units. The intercept of 3.88 represents the value of y when x is zero, meaning that without any influence from x, y starts at 3.88. In this case, as the Latitude values increase from negative to positive as we move towards the equator(latitude 0) in the southern hemisphere, it leads to a very gradual decline in the wind speed, but the overall effect is miniscule.
