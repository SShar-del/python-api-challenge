# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
from pprint import pprint


# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 583

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    units="metric"
    query_url=f"{url}appid={weather_api_key}&units={units}&q="
    city_url = query_url + city

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat =  city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp =  city_weather['main']["temp_max"]
        city_humidity = city_weather['main']["humidity"]
        city_clouds = city_weather['clouds']["all"]
        city_wind = city_weather['wind']["speed"]
        city_country = city_weather['sys']["country"]
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# Processing Record 2 of Set 1 | makubetsu
# Processing Record 3 of Set 1 | kargat
# Processing Record 4 of Set 1 | kostel
# Processing Record 5 of Set 1 | cannonvale
# Processing Record 6 of Set 1 | bethel
# Processing Record 7 of Set 1 | anabar
# City not found. Skipping...
# Processing Record 8 of Set 1 | buka
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | constantia
# Processing Record 11 of Set 1 | iqaluit
# Processing Record 12 of Set 1 | lihue
# Processing Record 13 of Set 1 | hotan
# Processing Record 14 of Set 1 | lalitpur
# Processing Record 15 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 16 of Set 1 | grytviken
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | port elizabeth
# Processing Record 19 of Set 1 | isafjordur
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | ambovombe
# Processing Record 22 of Set 1 | chonchi
# Processing Record 23 of Set 1 | bel ombre
# Processing Record 24 of Set 1 | talnakh
# Processing Record 25 of Set 1 | hailey
# Processing Record 26 of Set 1 | borba
# Processing Record 27 of Set 1 | port-aux-francais
# Processing Record 28 of Set 1 | nikolayevsk-on-amure
# Processing Record 29 of Set 1 | yuncheng
# Processing Record 30 of Set 1 | wakkanai
# Processing Record 31 of Set 1 | yuzhno-kurilsk
# Processing Record 32 of Set 1 | gwadar
# Processing Record 33 of Set 1 | blackmans bay
# Processing Record 34 of Set 1 | tralee
# Processing Record 35 of Set 1 | tiksi
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 38 of Set 1 | puerto natales
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | whitehorse
# Processing Record 41 of Set 1 | hampton bays
# Processing Record 42 of Set 1 | fortuna
# Processing Record 43 of Set 1 | kone
# Processing Record 44 of Set 1 | nuku'alofa
# Processing Record 45 of Set 1 | aasiaat
# Processing Record 46 of Set 1 | edinburgh of the seven seas
# Processing Record 47 of Set 1 | bolsward
# Processing Record 48 of Set 1 | puerto deseado
# Processing Record 49 of Set 1 | medvezh'yegorsk
# Processing Record 50 of Set 1 | port alfred
# Processing Record 0 of Set 2 | ust-nera
# Processing Record 1 of Set 2 | klyuchi
# Processing Record 2 of Set 2 | mandan
# Processing Record 3 of Set 2 | nova sintra
# Processing Record 22 of Set 3 | ilulissat
# Processing Record 23 of Set 3 | hamilton
# Processing Record 24 of Set 3 | longyearbyen
# Processing Record 25 of Set 3 | itaituba
# Processing Record 26 of Set 3 | choibalsan
# Processing Record 27 of Set 3 | inverell
# Processing Record 28 of Set 3 | san ignacio
# Processing Record 29 of Set 3 | at taj
# Processing Record 30 of Set 3 | pano aqil
# Processing Record 31 of Set 3 | kashira
# Processing Record 32 of Set 3 | nouadhibou
# Processing Record 33 of Set 3 | hugo
# Processing Record 34 of Set 3 | nalerigu
# City not found. Skipping...
# Processing Record 35 of Set 3 | hithadhoo
# Processing Record 36 of Set 3 | ulsteinvik
# Processing Record 37 of Set 3 | nuuk
# Processing Record 38 of Set 3 | xingcheng
# Processing Record 39 of Set 3 | marka
# Processing Record 40 of Set 3 | isiro
# Processing Record 41 of Set 3 | kailua-kona
# Processing Record 42 of Set 3 | smithers
# Processing Record 43 of Set 3 | arar
# Processing Record 44 of Set 3 | cambria
# Processing Record 45 of Set 3 | stephenville
# Processing Record 46 of Set 3 | villa de arriaga
# Processing Record 47 of Set 3 | pathein
# Processing Record 48 of Set 3 | anadyr
# Processing Record 49 of Set 3 | jian'ou
# Processing Record 0 of Set 4 | saarijarvi
# Processing Record 1 of Set 4 | stanley
# Processing Record 2 of Set 4 | yulin
# Processing Record 3 of Set 4 | seka
# Processing Record 4 of Set 4 | hasaki
# Processing Record 5 of Set 4 | broken hill
# Processing Record 6 of Set 4 | saipan
# Processing Record 7 of Set 4 | labrador city
# Processing Record 8 of Set 4 | kill devil hills
# Processing Record 9 of Set 4 | lata
# Processing Record 10 of Set 4 | pangobilian
# Processing Record 11 of Set 4 | stara vyzhivka
# Processing Record 12 of Set 4 | kamloops
# Processing Record 13 of Set 4 | agat village
# Processing Record 14 of Set 4 | kristiansund
# Processing Record 15 of Set 4 | es castell
# Processing Record 16 of Set 4 | chamical
# Processing Record 17 of Set 4 | erzincan
# Processing Record 18 of Set 4 | fort st. john
# Processing Record 19 of Set 4 | jayapura
# Processing Record 20 of Set 4 | ivrindi
# Processing Record 21 of Set 4 | enewetak
# Processing Record 22 of Set 4 | lusambo
# Processing Record 23 of Set 4 | bredasdorp
# Processing Record 24 of Set 4 | al jawf
# Processing Record 25 of Set 4 | salinas victoria
# Processing Record 26 of Set 4 | utrik
# Processing Record 27 of Set 4 | kittila
# Processing Record 28 of Set 4 | yanchep
# Processing Record 29 of Set 4 | labasa
# Processing Record 30 of Set 4 | bubaque
# Processing Record 31 of Set 4 | kawm umbu
# Processing Record 32 of Set 4 | salalah
# Processing Record 33 of Set 4 | qaqortoq
# Processing Record 34 of Set 4 | yendi
# Processing Record 35 of Set 4 | tsiombe
# Processing Record 36 of Set 4 | kingston
# Processing Record 37 of Set 4 | mount gambier
# Processing Record 38 of Set 4 | ta`u
# Processing Record 39 of Set 4 | boyolangu
# Processing Record 40 of Set 4 | sinabang
# Processing Record 41 of Set 4 | nar'yan-mar
# Processing Record 42 of Set 4 | san-pedro
# Processing Record 43 of Set 4 | tura
# Processing Record 44 of Set 4 | sao jose da coroa grande
# Processing Record 45 of Set 4 | vorgashor
# Processing Record 46 of Set 4 | quiberon
# Processing Record 47 of Set 4 | portland
# Processing Record 48 of Set 4 | iskateley
# Processing Record 49 of Set 4 | thompson
# Processing Record 0 of Set 5 | zhanga buqtyrma
# Processing Record 1 of Set 5 | shimoda
# Processing Record 2 of Set 5 | tabou
# Processing Record 3 of Set 5 | puerto baquerizo moreno
# Processing Record 4 of Set 5 | machico
# Processing Record 5 of Set 5 | midvagur
# Processing Record 6 of Set 5 | antsohihy
# Processing Record 7 of Set 5 | mount pleasant
# Processing Record 8 of Set 5 | udachny
# Processing Record 9 of Set 5 | fisterra
# Processing Record 10 of Set 5 | sarangani
# Processing Record 11 of Set 5 | kirakira
# Processing Record 12 of Set 5 | eydhafushi
# Processing Record 13 of Set 5 | uige
# Processing Record 14 of Set 5 | oum hadjer
# Processing Record 15 of Set 5 | dubrovnik
# Processing Record 16 of Set 5 | georgetown
# Processing Record 17 of Set 5 | palmer
# Processing Record 18 of Set 5 | qeshm
# Processing Record 19 of Set 5 | nadym
# Processing Record 20 of Set 5 | rongelap
# Processing Record 21 of Set 5 | pirane
# Processing Record 22 of Set 5 | arkhangel'sk
# Processing Record 23 of Set 5 | port douglas
# Processing Record 24 of Set 5 | howrah
# Processing Record 25 of Set 5 | uvira
# Processing Record 26 of Set 5 | siklos
# Processing Record 27 of Set 5 | olavarria
# Processing Record 28 of Set 5 | freetown
# Processing Record 29 of Set 5 | kuta
# Processing Record 30 of Set 5 | obo
# Processing Record 31 of Set 5 | des moines
# Processing Record 32 of Set 5 | waingapu
# Processing Record 33 of Set 5 | mahibadhoo
# Processing Record 34 of Set 5 | kharovsk
# Processing Record 35 of Set 5 | martuk
# Processing Record 36 of Set 5 | kupang
# Processing Record 37 of Set 5 | kitimat
# Processing Record 38 of Set 5 | ghanzi
# Processing Record 39 of Set 5 | the pas
# Processing Record 40 of Set 5 | pouso alegre
# Processing Record 41 of Set 5 | jamestown
# Processing Record 42 of Set 5 | tommot
# Processing Record 43 of Set 5 | guerrero negro
# Processing Record 44 of Set 5 | mpulungu
# Processing Record 45 of Set 5 | nemuro
# Processing Record 46 of Set 5 | botou
# Processing Record 47 of Set 5 | kapa'a
# Processing Record 48 of Set 5 | acarau
# Processing Record 49 of Set 5 | puerto san jose
# Processing Record 0 of Set 6 | la ronge
# Processing Record 1 of Set 6 | haiku-pauwela
# Processing Record 2 of Set 6 | kavaratti
# Processing Record 3 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 4 of Set 6 | impfondo
# Processing Record 5 of Set 6 | kavieng
# Processing Record 6 of Set 6 | praia
# Processing Record 7 of Set 6 | pudozh
# Processing Record 8 of Set 6 | fujin
# Processing Record 9 of Set 6 | tarko-sale
# Processing Record 10 of Set 6 | akureyri
# Processing Record 11 of Set 6 | saldanha
# Processing Record 12 of Set 6 | namibe
# Processing Record 13 of Set 6 | baki
# Processing Record 14 of Set 6 | cabo san lucas
# Processing Record 15 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 16 of Set 6 | kudymkar
# Processing Record 17 of Set 6 | uturoa
# Processing Record 18 of Set 6 | new norfolk
# Processing Record 19 of Set 6 | colonia
# Processing Record 20 of Set 6 | san patricio
# Processing Record 21 of Set 6 | oranjemund
# Processing Record 22 of Set 6 | cable beach
# City not found. Skipping...
# Processing Record 23 of Set 6 | brokopondo
# Processing Record 24 of Set 6 | pedernales
# Processing Record 25 of Set 6 | tindouf
# Processing Record 26 of Set 6 | parabel'
# Processing Record 27 of Set 6 | ampanihy
# Processing Record 28 of Set 6 | nagato
# Processing Record 29 of Set 6 | orsa
# Processing Record 30 of Set 6 | ciudad lazaro cardenas
# Processing Record 31 of Set 6 | new plymouth
# Processing Record 32 of Set 6 | itoman
# Processing Record 33 of Set 6 | huocheng
# City not found. Skipping...
# Processing Record 34 of Set 6 | jijel
# Processing Record 35 of Set 6 | jiujiang
# Processing Record 36 of Set 6 | port lincoln
# Processing Record 37 of Set 6 | hadibu
# Processing Record 38 of Set 6 | minas de marcona
# Processing Record 39 of Set 6 | zhalantun
# Processing Record 40 of Set 6 | kapuskasing
# Processing Record 41 of Set 6 | kodok
# City not found. Skipping...
# Processing Record 42 of Set 6 | mccook
# Processing Record 43 of Set 6 | slavutych
# Processing Record 44 of Set 6 | aver-o-mar
# Processing Record 45 of Set 6 | tolanaro
# Processing Record 46 of Set 6 | holualoa
# Processing Record 47 of Set 6 | ridgecrest
# Processing Record 48 of Set 6 | laranjeiras do sul
# Processing Record 49 of Set 6 | princeville
# Processing Record 0 of Set 7 | tromso
# Processing Record 1 of Set 7 | kruisfontein
# Processing Record 2 of Set 7 | mar del plata
# Processing Record 3 of Set 7 | lethem
# Processing Record 4 of Set 7 | manatutu
# City not found. Skipping...
# Processing Record 5 of Set 7 | zahedan
# Processing Record 6 of Set 7 | weno
# Processing Record 7 of Set 7 | saint-jean-de-monts
# Processing Record 8 of Set 7 | bosansko grahovo
# Processing Record 9 of Set 7 | nizhnekamsk
# Processing Record 10 of Set 7 | vila franca do campo
# Processing Record 11 of Set 7 | lompoc
# Processing Record 12 of Set 7 | punta del este
# Processing Record 13 of Set 7 | pont-audemer
# Processing Record 14 of Set 7 | kerikeri
# Processing Record 15 of Set 7 | bonthe
# Processing Record 16 of Set 7 | miguel ahumada
# Processing Record 17 of Set 7 | pundong
# Processing Record 18 of Set 7 | tazovsky
# Processing Record 19 of Set 7 | lensk
# Processing Record 20 of Set 7 | omaruru
# Processing Record 21 of Set 7 | sawa sawa
# Processing Record 22 of Set 7 | tocopilla
# Processing Record 23 of Set 7 | ongjin
# Processing Record 24 of Set 7 | upata
# Processing Record 25 of Set 7 | anibare
# City not found. Skipping...
# Processing Record 26 of Set 7 | borogontsy
# Processing Record 27 of Set 7 | concepcion
# Processing Record 28 of Set 7 | parambu
# Processing Record 29 of Set 7 | baganga
# Processing Record 30 of Set 7 | gamba
# Processing Record 31 of Set 7 | douglas
# Processing Record 32 of Set 7 | mogadishu
# Processing Record 33 of Set 7 | trondheim
# Processing Record 34 of Set 7 | hafizabad
# Processing Record 24 of Set 10 | new glasgow
# Processing Record 25 of Set 10 | bol'shoye boldino
# Processing Record 26 of Set 10 | siwa oasis
# Processing Record 27 of Set 10 | lockwood
# Processing Record 28 of Set 10 | ancud
# Processing Record 29 of Set 10 | riohacha
# Processing Record 30 of Set 10 | thinadhoo
# Processing Record 31 of Set 10 | turpan
# Processing Record 32 of Set 10 | tanumah
# Processing Record 33 of Set 10 | bakchar
# Processing Record 34 of Set 10 | pirallahi
# Processing Record 35 of Set 10 | tyukhtet
# Processing Record 36 of Set 10 | pacocha
# Processing Record 37 of Set 10 | crane
# Processing Record 38 of Set 10 | labytnangi
# Processing Record 39 of Set 10 | daru
# Processing Record 40 of Set 10 | yamada
# Processing Record 41 of Set 10 | mount isa
# Processing Record 42 of Set 10 | al hufuf
# Processing Record 43 of Set 10 | dayr al balah
# Processing Record 44 of Set 10 | mahavelona
# Processing Record 45 of Set 10 | huarmey
# Processing Record 46 of Set 10 | puerto cabezas
# Processing Record 47 of Set 10 | freeport
# Processing Record 48 of Set 10 | gudul
# Processing Record 49 of Set 10 | coyhaique
# Processing Record 0 of Set 11 | tazacorte
# Processing Record 1 of Set 11 | fernie
# Processing Record 2 of Set 11 | vernon
# Processing Record 3 of Set 11 | itanhem
# Processing Record 4 of Set 11 | takoradi
# Processing Record 5 of Set 11 | mbandaka
# Processing Record 6 of Set 11 | whyalla stuart
# City not found. Skipping...
# Processing Record 7 of Set 11 | vila velha
# Processing Record 8 of Set 11 | arish
# Processing Record 9 of Set 11 | kidal
# Processing Record 10 of Set 11 | tabas
# Processing Record 11 of Set 11 | alta
# Processing Record 12 of Set 11 | dunedin
# Processing Record 13 of Set 11 | kuanda
# Processing Record 14 of Set 11 | el granada
# Processing Record 15 of Set 11 | noumea
# Processing Record 16 of Set 11 | buy
# Processing Record 17 of Set 11 | jwaneng
# Processing Record 18 of Set 11 | velikiye luki
# Processing Record 19 of Set 11 | nampula
# Processing Record 20 of Set 11 | muzaffargarh
# Processing Record 21 of Set 11 | noosa heads
# Processing Record 22 of Set 11 | eenhana
# Processing Record 23 of Set 11 | ewo
# Processing Record 24 of Set 11 | totness
# Processing Record 25 of Set 11 | kongsberg
# Processing Record 26 of Set 11 | novofedorivka
# Processing Record 27 of Set 11 | queenstown
# Processing Record 28 of Set 11 | eyl
# Processing Record 29 of Set 11 | mata-utu
# Processing Record 30 of Set 11 | hohhot
# Processing Record 31 of Set 11 | union
# Processing Record 32 of Set 11 | coquimbo
# Processing Record 33 of Set 11 | flin flon
# Processing Record 34 of Set 11 | talara
# Processing Record 35 of Set 11 | roanoke
# Processing Record 36 of Set 11 | beloretsk
# Processing Record 37 of Set 11 | codrington
# Processing Record 38 of Set 11 | hami
# Processing Record 39 of Set 11 | ukata
# Processing Record 40 of Set 11 | sydney mines
# Processing Record 41 of Set 11 | beira
# Processing Record 42 of Set 11 | bor
# Processing Record 43 of Set 11 | saint-joseph
# Processing Record 44 of Set 11 | dzerzhinskoye
# Processing Record 45 of Set 11 | chibougamau
# Processing Record 46 of Set 11 | ilebo
# Processing Record 47 of Set 11 | little cayman
# City not found. Skipping...
# Processing Record 48 of Set 11 | ituango
# Processing Record 49 of Set 11 | bridgewater
# Processing Record 0 of Set 12 | misratah
# Processing Record 1 of Set 12 | bamboo flat
# Processing Record 2 of Set 12 | geraldton
# Processing Record 3 of Set 12 | formosa
# Processing Record 4 of Set 12 | pitogo
# Processing Record 5 of Set 12 | mikun'
# Processing Record 6 of Set 12 | mermoz boabab
# Processing Record 7 of Set 12 | espargos
# City not found. Skipping...
# Processing Record 8 of Set 12 | mugia
# Processing Record 9 of Set 12 | masterton
# Processing Record 10 of Set 12 | prince rupert
# Processing Record 11 of Set 12 | tutoia
# Processing Record 12 of Set 12 | neiafu
# Processing Record 13 of Set 12 | la puebla de montalban
# Processing Record 14 of Set 12 | pariaman
# Processing Record 15 of Set 12 | salinopolis
# Processing Record 16 of Set 12 | porto murtinho
# Processing Record 17 of Set 12 | horta
# Processing Record 18 of Set 12 | ushtobe
# Processing Record 19 of Set 12 | tamanrasset
# Processing Record 20 of Set 12 | satana
# Processing Record 21 of Set 12 | remire-montjoly
# Processing Record 22 of Set 12 | verkhovyna
# Processing Record 23 of Set 12 | revda
# Processing Record 24 of Set 12 | carloforte
# Processing Record 25 of Set 12 | benxi
# Processing Record 26 of Set 12 | susuman
# Processing Record 27 of Set 12 | syktyvkar
# Processing Record 28 of Set 12 | port moresby
# Processing Record 29 of Set 12 | kurmuk
# Processing Record 30 of Set 12 | altay
# Processing Record 31 of Set 12 | benjamin constant
# Processing Record 32 of Set 12 | lunao
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          551
# Lat           551
# Lng           551
# Max Temp      551
# Humidity      551
# Cloudiness    551
# Wind Speed    551
# Country       551
# Date          551
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   adamstown -25.0660 -130.1015     16.62        59          98        9.21
# 1   makubetsu  45.3714  141.8211     19.29        94         100        7.16
# 2      kargat  55.1956   80.2811     12.57        92          57        2.51
# 3      kostel  42.8887   25.9950     24.74        51          98        1.83
# 4  cannonvale -20.2833  148.7000     20.66        75          89        3.46
#
#   Country        Date
# 0      PN  1724259668
# 1      JP  1724259669
# 2      RU  1724259670
# 3      BG  1724259671
# 4      AU  1724259672

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         adamstown -25.0660 -130.1015     16.62        59          98
# 1         makubetsu  45.3714  141.8211     19.29        94         100
# 2            kargat  55.1956   80.2811     12.57        92          57
# 3            kostel  42.8887   25.9950     24.74        51          98
# 4        cannonvale -20.2833  148.7000     20.66        75          89
#
#          Wind Speed Country        Date
# City_ID
# 0              9.21      PN  1724259668
# 1              7.16      JP  1724259669
# 2              2.51      RU  1724259670
# 3              1.83      BG  1724259671
# 4              3.46      AU  1724259672

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values, edgecolor="black")


# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature(C)')
plt.title(f"City Max Latitude vs Temperature(2024-06-17)")
plt.grid()


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values,y_values, edgecolor="black")


# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f"City Latitude vs Humidity(2024-06-17)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values,y_values, edgecolor="black")


# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title(f"City Latitude vs Cloudiness(2024-06-17)")
plt.grid()


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values, edgecolor="black")


# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')
plt.title(f"City Latitude vs Wind Speed(2024-06-17)")
plt.grid()


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression_plots(x_values, y_values, title, x_label, y_label):
    
# Perform a linear regression on temperature vs. latitude
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)

# Get regression values
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
# Annotate the line equation
   
    plt.annotate(line_eq,(0.05, 0.95),xycoords='axes fraction', verticalalignment='top', fontsize=15,color="red")
    

 #Label the plot
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
   

# Print r^2 value
    print(f"The r^2-value is: {rvalue**2}")

# Show plot
    plt.show()
    
    

    return

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=city_data_df.loc[city_data_df["Lat"]>= 0]
# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        makubetsu  45.3714  141.8211     19.29        94         100
# 2           kargat  55.1956   80.2811     12.57        92          57
# 3           kostel  42.8887   25.9950     24.74        51          98
# 5           bethel  41.3712  -73.4140     21.68        61          75
# 6             buka  40.8108   69.1986     24.83        23          99
#
#          Wind Speed Country        Date
# City_ID
# 1              7.16      JP  1724259669
# 2              2.51      RU  1724259670
# 3              1.83      BG  1724259671
# 5              4.12      US  1724259472
# 6              2.16      UZ  1724259676

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df.loc[city_data_df["Lat"]< 0]
# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           adamstown -25.0660 -130.1015     16.62        59          98
# 4          cannonvale -20.2833  148.7000     20.66        75          89
# 7        puerto ayora  -0.7393  -90.3518     20.86        92          93
# 13          grytviken -54.2811  -36.5092     -4.60        71          31
# 14           hermanus -34.4187   19.2345     11.00        58          56
#
#          Wind Speed Country        Date
# City_ID
# 0              9.21      PN  1724259668
# 4              3.46      AU  1724259672
# 7              3.13      EC  1724259677
# 13            10.18      GS  1724259686
# 14             6.11      ZA  1724259688

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_regression_plots(northern_hemi_df['Lat'],northern_hemi_df['Max Temp'],"Latitude Vs. Max temp","Latitude","Max temp" )
# Out:
# The r^2-value is: 0.5151126036245551

# %%
# Linear regression on Southern Hemisphere
plt.clf()
linear_regression_plots(southern_hemi_df['Lat'],southern_hemi_df['Max Temp'],"Latitude Vs. Max temp","Latitude","Max temp" )
# Out:
# The r^2-value is: 0.6709238433929586

# %% [markdown]
# **Discussion about the linear relationship:** The equation y=−0.29x+33.35 (y=slope*x + intercept) describes a linear relationship where y decreases as x increases. In this case, as the Latitude value increases as you go up north in the northern hemisphere, away from the equator (latitude 0), the max temp starts to decrease.The equation y=0.52x+31.08 (y=slope*x + intercept)on the other hand, describes a linear relationship where y increases as x increases. In this case, as the Latitude value increases, going from -values to +values,the Max temp of the area increases as you go up north in the southern hemisphere, towards the equator where the latitude is 0.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.clf()
linear_regression_plots(northern_hemi_df['Lat'],northern_hemi_df['Humidity'],"Latitude Vs. Humidity","Latitude","Humidity" )
# Out:
# The r^2-value is: 0.0007849410307800594

# %%
# Southern Hemisphere
plt.clf()
linear_regression_plots(southern_hemi_df['Lat'],southern_hemi_df['Humidity'],"Latitude Vs. Humidity","Latitude","Humidity" )
# Out:
# The r^2-value is: 0.03215369843942743

# %% [markdown]
# **Discussion about the linear relationship:** The equation y=−0.03x+68.25 (y=slope*x + intercept) describes a linear relationship where y decreases slightly as x increases. In this case, as the Latitude value increases, humidity gradually declines as you move up north from the equator(latitude 0) in the northern hemisphere.The equation y=−0.31x+62.3 (y=slope*x + intercept) describes a linear relationship where y decreases as x increases. In this case, an increase in the latitude value from negative to positive in the southern hemisphere i.e a move up towards the equator(latitude 0) leads to a gradual decline in the humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.clf()
linear_regression_plots(northern_hemi_df['Lat'],northern_hemi_df['Cloudiness'],"Latitude Vs. Cloudiness","Latitude","Cloudiness" )
# Out:
# The r^2-value is: 0.0003171725951194694

# %%
# Southern Hemisphere
plt.clf()
linear_regression_plots(southern_hemi_df['Lat'],southern_hemi_df['Cloudiness'],"Latitude Vs. Cloudiness","Latitude","Cloudiness" )
# Out:
# The r^2-value is: 0.0009698703856515532

# %% [markdown]
# **Discussion about the linear relationship:** The equation y=−0.4x+58.2 describes a linear relationship where y decreases as x increases. In this case, an increase in the Latitude value leads to a gradual decline in the cloudiness as you move away from the equator(latitude 0) in the northern hemisphere.The equation y=−0.08x+48.97 describes a linear relationship where y decreases as x increases. In this case, as the Latitude value increases from negative to positive moving up north in the southern hemisphere towards the equator(latitude 0) it leads to a decrease in cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.clf()
linear_regression_plots(northern_hemi_df['Lat'],northern_hemi_df['Wind Speed'],"Latitude Vs. Wind Speed","Latitude","Wind Speed" )
# Out:
# The r^2-value is: 8.600426829797148e-05

# %%
# Southern Hemisphere
plt.clf()
linear_regression_plots(southern_hemi_df['Lat'],southern_hemi_df['Wind Speed'],"Latitude Vs. Wind Speed","Latitude","Wind Speed" )
# Out:
# The r^2-value is: 0.0015572099048896395

# %% [markdown]
# **Discussion about the linear relationship:** The equation y=−0.0x+3.51 describes a situation where the dependent variable y remains constant regardless of the value of the independent variable x. This means that there is no relationship between x and y; y does not change as x changes. In this case, as the latitude increases as you move away from the equator(latitude 0) in the northern hemisphere, there is no impact on the wind speed as a result of it.The equation y=−0.01x+4.51 describes a linear relationship where y decreases slightly as x increases. In this case, as the Latitude values increase from negative to positive as we move towards the equator(latitude 0) in the southern hemisphere, it leads to a very gradual decline in the wind speed, but the overall effect is miniscule.
